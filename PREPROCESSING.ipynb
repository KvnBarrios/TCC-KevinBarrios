# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kevin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
smh = """
1. Introdução
1.1. Objetivo
O propósito fundamental deste documento é articular, com clareza e minúcia, os requisitos técnicos e operacionais do Sistema de Monitoramento de Hidrelétricas (SMH). Projetado como uma ferramenta crucial, ele visa atender a complexa rede de profissionais envolvidos, desde engenheiros e analistas até os responsáveis pela tomada de decisões nas organizações hidrelétricas.

1.2. Escopo
SMH tem por objetivo ser o alicerce digital na supervisão e controle das atividades de usinas hidrelétricas. Através de suas funcionalidades, será possível monitorar as condições e o desempenho dos equipamentos, analisar a qualidade da água, detectar desgastes prematuros em turbinas e barragens, e prever possíveis falhas ou inundações.

1.3. Definições, Acrônimos e Abreviações

SMH: Sistema de Monitoramento de Hidrelétricas
ANA: Agência Nacional de Águas
ONS: Operador Nacional do Sistema Elétrico
1.4. Referências
[1] "Padrões de Desempenho de Usinas Hidrelétricas" - ANA
[2] "Sistema de Supervisão e Controle de Dados" - ONS
[3] "Diretrizes para Monitoramento de Infraestrutura Hídrica" - IBAMA

1.5. Visão Geral
Este documento visa oferecer uma visão completa do SMH, delineando desde requisitos técnicos até os específicos, abordando cada faceta do sistema em detalhes.

2. Descrição Geral
2.1. Requisitos Funcionais
O SMH contará com uma série de módulos integrados:

Módulo de Sensores: Integrará informações de sensores espalhados pela usina, abrangendo desde temperatura até níveis de vibração.
Módulo de Alerta: Capaz de identificar situações anormais e disparar alertas para os responsáveis, evitando catástrofes.
Módulo Analítico: Conduzirá análises profundas, apresentando relatórios ricos sobre o estado geral da usina.
2.2. Requisitos de Interface
A interface do SMH será intuitiva, com dashboards personalizáveis. Ela será projetada para ser acessível em diversos dispositivos, desde grandes monitores até tablets e smartphones. A integração com outros sistemas, como o SCADA, será facilitada por meio de APIs dedicadas.

2.3. Atributos de Qualidade

Confiabilidade: Garantir operação contínua 24/7, identificando e corrigindo falhas de forma autônoma.
Eficiência: Respostas rápidas mesmo sob condições de alta demanda.
Adaptabilidade: Flexibilidade para acomodar novos requisitos ou mudanças em regulamentações.
2.4. Características dos Usuários
O SMH será usado por uma gama variada de profissionais. Portanto, ele contará com diferentes níveis de acesso, garantindo que cada perfil de usuário tenha acesso apenas às funcionalidades pertinentes à sua função.

2.5. Restrições
O SMH será desenvolvido seguindo as diretrizes rigorosas impostas pelos órgãos reguladores e precisará estar em constante conformidade com essas normas.

2.6. Suposições e Dependências
Supõe-se que a infraestrutura das hidrelétricas, como energia e conectividade, será constante e confiável. Qualquer interrupção nesses serviços pode afetar a eficácia do SMH.

3. Requisitos Específicos
3.1. Requisitos de Desempenho
A alta performance é crucial. O SMH será desenvolvido para ser multi-threaded, garantindo que grandes volumes de dados sejam processados simultaneamente sem degradar a performance.

3.2. Requisitos de Segurança
Um protocolo rigoroso de autenticação será implementado. Todos os dados serão criptografados, e regularmente serão realizadas auditorias de segurança.

4. Anexo
4.1. Recursos e Técnicas Utilizados
Foram realizadas diversas sessões de brainstorming, consultas com especialistas internacionais em monitoramento hidrelétrico e revisões literárias extensas.

4.2. Lista de Perguntas
Além das questões já mencionadas, foram feitas indagações como:

Como a integração de novos sensores pode ser facilitada?
Qual é o tempo médio para resposta em casos de emergência atualmente?
Há alguma tecnologia emergente que deveríamos considerar?
4.3. Contatos
Eng. Rafael Soares, Supervisor Técnico, Usina Hidrelétrica Xingu, (555) 123-4567, 25 de Agosto de 2023.
Dra. Carolina Mendes, Diretora de Operações, Usina Hidrelétrica Paranapanema, (555) 789-0123, 28 de Agosto de 2023.
"""

# %%
scta = """
1. Introdução

1.1. Objetivo
Este documento visa definir os requisitos funcionais, técnicos e de negócio para o desenvolvimento do Sistema de Controle de Tráfego Aéreo (SCTA). Destina-se aos gestores de projeto, desenvolvedores, testadores, stakeholders e utilizadores finais do sistema.

1.2. Escopo
O SCTA é um sistema de software destinado a facilitar a gestão eficiente e segura de tráfego aéreo. Ele abordará a detecção de aeronaves, monitorização em tempo real, fornecimento de dados relevantes aos controladores de tráfego aéreo e a coordenação de rotas de voo.

1.3. Definições, acrônimos e abreviações
SCTA: Sistema de Controle de Tráfego Aéreo.
ATC: Controlador de Tráfego Aéreo.
FAA: Administração Federal de Aviação.
ICAO: Organização de Aviação Civil Internacional.

1.4. Referências
[1] "IEEE Recommended Practice for Software Requirements Specifications".
[2] "ISO/IEC/IEEE 29148:2011".
[3] "FAA Order JO 7110.65".

1.5. Visão geral
Este documento de especificação de requisitos é composto por quatro seções principais: Introdução, Descrição Geral, Requisitos Específicos e Anexo.

2. Descrição Geral

2.1. Requisitos funcionais
O SCTA deve ser capaz de monitorar e gerenciar efetivamente o tráfego aéreo, fornecer rotas de voo otimizadas e alertar os controladores de tráfego aéreo sobre possíveis riscos.

2.2. Requisitos de interface
O SCTA deve ser compatível com os sistemas de hardware e software existentes, incluindo sistemas de radar e de comunicação aeronáutica.

2.3. Atributos de qualidade
O SCTA deve ter uma alta confiabilidade e desempenho para responder em tempo real a situações de emergência.

2.4. Características dos usuários
Os usuários principais do SCTA são controladores de tráfego aéreo treinados e certificados.

2.5. Restrições
O SCTA deve cumprir todas as leis e regulamentos pertinentes, incluindo os definidos pela FAA e ICAO.

2.6. Suposições e dependências
O SCTA será operado em um ambiente de controle de tráfego aéreo e assumimos que todas as aeronaves equipadas estão operando no espaço aéreo controlado pelo sistema.

3. Requisitos específicos

3.1. Requisitos de desempenho
O SCTA deve ser capaz de processar dados de voo de centenas de aeronaves simultaneamente e deve ser capaz de responder a situações de emergência em menos de um segundo.

3.2. Requisitos de segurança
O SCTA deve garantir a confidencialidade, integridade e disponibilidade dos dados que processa. Além disso, o SCTA deve ser capaz de se recuperar rapidamente de falhas e garantir a continuidade das operações.

4. Anexo
O anexo inclui um plano de manutenção detalhado para o SCTA, bem como diagramas de fluxo de dados e de interface do usuário. Também é fornecida uma lista de todas as partes interessadas que foram consultadas durante a criação deste documento de requisitos.

4.1. Recursos e técnicas utilizados
Várias técnicas e recursos foram usados para a extração de requisitos. Isso inclui entrevistas com controladores de tráfego aéreo, workshops com stakeholders, revisão de documentos técnicos, e uso de ferramentas de modelagem de software.

4.2. Lista de perguntas
As perguntas feitas durante as entrevistas e workshops incluíam questões como:

Quais são os principais desafios que você enfrenta atualmente na gestão do tráfego aéreo?
Que tipo de funcionalidades você gostaria de ver em um sistema ideal de controle de tráfego aéreo?
Quais são as principais áreas que necessitam de melhorias no atual sistema de controle de tráfego aéreo?
4.3. Contatos
Os principais contatos durante o processo de elicitação de requisitos incluíram:

John Doe, Controlador de Tráfego Aéreo Senior, Aeroporto Internacional JFK, (555) 123-4567, 22 de Janeiro de 2023
Jane Smith, Gerente de Operações, Administração Federal de Aviação, (555) 765-4321, 25 de Janeiro de 2023
"""

# %%
smpu = """1. Introdução

1.1. Objetivo
Este documento define os requisitos para o desenvolvimento do Sistema de Monitoramento de Pacientes em UTI (SMPU), um software complexo que auxilia os profissionais de saúde, fornecendo informações em tempo real sobre o estado clínico dos pacientes internados em Unidades de Terapia Intensiva. O sistema será usado por médicos, enfermeiros, técnicos em saúde e outros profissionais de saúde para monitorar sinais vitais, estado do paciente e registrar mudanças na condição dos pacientes.

1.2. Escopo
O SMPU será capaz de coletar, processar e exibir uma série de métricas vitais, incluindo frequência cardíaca, pressão arterial, oximetria de pulso, temperatura corporal, frequência respiratória e níveis de consciência. Além disso, o sistema deve integrar-se aos principais Sistemas de Informação Hospitalar (SIH) para permitir a atualização contínua do registro eletrônico de saúde do paciente. O SMPU não tem como objetivo substituir a avaliação clínica por profissionais de saúde, mas fornecer uma ferramenta para ajudar na monitorização dos pacientes em tempo real.

1.3. Definições, acrônimos e abreviações

UTI: Unidade de Terapia Intensiva
SIH: Sistema de Informação Hospitalar
EHR: Electronic Health Record (Registro Eletrônico de Saúde)
BPM: Batimentos por Minuto
SpO2: Saturação de Oxigênio
GCS: Escala de Coma de Glasgow
API: Application Programming Interface
HL7: Health Level Seven, um conjunto de normas internacionais para transferência de dados clínicos e administrativos entre aplicativos de software usados por serviços de saúde.
1.4. Referências

ISO 13485:2016 - Sistemas de Gestão da Qualidade para Dispositivos Médicos
ISO 14971:2019 - Gestão de Riscos de Dispositivos Médicos
GDPR: Regulamento Geral de Proteção de Dados
LGPD: Lei Geral de Proteção de Dados Pessoais
1.5. Visão geral
A Especificação de Requisitos inclui uma descrição dos requisitos funcionais, de interface, de desempenho e de sistema, bem como restrições e dependências do sistema. O sistema tem como objetivo central oferecer aos profissionais de saúde uma ferramenta robusta e confiável para o monitoramento contínuo de pacientes em estado crítico.

2. Descrição Geral

2.1. Requisitos funcionais

Coletar dados dos dispositivos médicos em tempo real: O sistema deve ser capaz de coletar dados de vários tipos de dispositivos médicos, como monitores de sinais vitais, ventiladores e bombas de infusão. Esses dados incluem, mas não se limitam a, frequência cardíaca, pressão arterial, saturação de oxigênio no sangue, frequência respiratória, temperatura corporal e níveis de consciência medidos pela escala de coma de Glasgow.

Processar e analisar os dados coletados e gerar informações acionáveis: O sistema deve processar e analisar os dados coletados para identificar tendências e padrões. O sistema deve gerar informações acionáveis com base na análise dos dados. Por exemplo, o sistema pode identificar se a frequência cardíaca de um paciente está fora do intervalo normal e gerar um alerta para os profissionais de saúde.

Exibir dados processados em uma interface amigável: O sistema deve exibir os dados processados de uma maneira fácil de entender. Isso pode incluir gráficos, tabelas e outras representações visuais dos dados.

Gerar alertas baseados em parâmetros definidos pelos profissionais de saúde: O sistema deve permitir que os profissionais de saúde definam parâmetros para cada paciente. Se os dados coletados caírem fora desses parâmetros, o sistema deve gerar um alerta.

Registrar e armazenar todos os eventos do paciente, incluindo alterações em parâmetros vitais e alertas gerados: O sistema deve registrar todos os eventos relacionados ao paciente, incluindo alterações em parâmetros vitais e alertas gerados. Estes registros devem ser armazenados de forma segura e devem ser facilmente acessíveis para revisão e análise.

Fornecer uma interface para profissionais de saúde revisarem e modificarem parâmetros de alerta: O sistema deve fornecer uma interface fácil de usar que permite aos profissionais de saúde revisar e modificar os parâmetros de alerta para cada paciente.

Sincronizar em tempo real com o Registro Eletrônico de Saúde (EHR) do paciente: O sistema deve ser capaz de sincronizar em tempo real com o EHR do paciente. Isso permite que as informações mais recentes sobre o estado do paciente sejam compartilhadas com todos os profissionais de saúde envolvidos no cuidado do paciente.

2.2. Requisitos de interface

Interface de usuário intuitiva e fácil de usar para visualização de dados em tempo real: A interface de usuário do sistema deve ser intuitiva e fácil de usar. Ela deve permitir que os profissionais de saúde visualizem os dados do paciente em tempo real de forma clara e compreensível.

Notificações claras e distinguíveis para alertas: Quando um alerta é gerado, o sistema deve fornecer uma notificação clara e distinguível para o profissional de saúde. A notificação deve indicar a natureza do alerta e fornecer informações relevantes sobre o estado do paciente.

Capacidade de personalizar a exibição de dados para cada usuário: Cada usuário do sistema deve ser capaz de personalizar a exibição de dados de acordo com suas preferências e necessidades. Isso pode incluir a escolha de quais métricas são exibidas e como elas são apresentadas.

Interfaces de comunicação padronizadas para integração com equipamentos médicos de várias marcas: O sistema deve usar interfaces de comunicação padronizadas, como HL7, para permitir a integração com uma ampla gama de equipamentos médicos de várias marcas.

API para troca segura de dados com SIH: O sistema deve fornecer uma API que permite a troca segura de dados com o SIH. A API deve ser projetada de acordo com os padrões de segurança e privacidade de dados para garantir que os dados do paciente sejam protegidos.

2.3. Atributos de qualidade

Alta disponibilidade e confiabilidade para garantir monitoramento contínuo e ininterrupto: O sistema deve ser altamente disponível e confiável. Ele deve ser projetado para garantir o monitoramento contínuo e ininterrupto dos pacientes na UTI. O sistema deve ser capaz de operar 24 horas por dia, 7 dias por semana, e deve ser capaz de recuperar rapidamente de falhas.

Desempenho robusto e responsivo para lidar com grande volume de dados em tempo real: O sistema deve ter um desempenho robusto e responsivo. Ele deve ser capaz de lidar com um grande volume de dados em tempo real e fornecer atualizações em tempo real para os profissionais de saúde.

Segurança de dados rigorosa para garantir a privacidade do paciente: O sistema deve implementar medidas de segurança de dados rigorosas para garantir a privacidade do paciente. Isso inclui a criptografia de dados em repouso e em trânsito, e a implementação de controles de acesso para garantir que apenas pessoas autorizadas possam acessar os dados do paciente.

Portabilidade para suportar uma variedade de dispositivos e sistemas operacionais: O sistema deve ser portátil e capaz de funcionar em uma variedade de dispositivos e sistemas operacionais. Isso permite que o sistema seja usado em uma variedade de ambientes de saúde.

2.4. Características dos usuários

Usuários finais serão profissionais de saúde com habilidades variadas em tecnologia: O sistema será usado por uma variedade de profissionais de saúde, incluindo médicos, enfermeiros, técnicos em saúde e outros. Estes usuários terão uma variedade de habilidades em tecnologia, e o sistema deve ser fácil de usar para todos eles.

Administradores do sistema terão conhecimento técnico avançado: Os administradores do sistema serão responsáveis pela manutenção e operação do sistema. Eles terão um conhecimento técnico avançado e estarão familiarizados com os sistemas de TI em ambientes de saúde.

2.5. Restrições

Conformidade com normas e regulamentos de dispositivos médicos e de privacidade de dados: O sistema deve estar em conformidade com todas as normas e regulamentos relevantes para dispositivos médicos e privacidade de dados. Isso inclui, mas não se limita a, ISO 13485 para sistemas de gestão da qualidade para dispositivos médicos, ISO 14971 para gestão de riscos de dispositivos médicos, GDPR para proteção de dados pessoais na União Europeia e LGPD para proteção de dados pessoais no Brasil.

Compatibilidade com a variedade de dispositivos médicos existentes no mercado: O sistema deve ser compatível com uma ampla variedade de dispositivos médicos existentes no mercado. Isso inclui monitores de sinais vitais, ventiladores, bombas de infusão e outros.

Disponibilidade de uma rede de comunicação confiável para transmissão de dados: O sistema requer uma rede de comunicação confiável para a transmissão de dados. Esta rede deve ser capaz de lidar com o volume de dados transmitidos pelo sistema e deve ser confiável para garantir a disponibilidade contínua do sistema.

2.6. Suposições e dependências

O sistema operacional em que o SMPU será instalado deve ser estável e seguro: O sistema será instalado em um sistema operacional que deve ser estável e seguro. A segurança do sistema operacional é essencial para a segurança geral do sistema.

A infraestrutura de TI do hospital deve ser capaz de suportar o volume de dados transmitidos pelo SMPU: O sistema será instalado em hospitais com uma infraestrutura de TI que deve ser capaz de suportar o volume de dados transmitidos pelo SMPU.

O pessoal de TI do hospital deve estar disponível para ajudar na instalação e manutenção do SMPU: O sistema requer apoio do pessoal de TI do hospital para instalação e manutenção. Este pessoal deve estar disponível e ter o conhecimento técnico necessário para apoiar o sistema.

3. Requisitos específicos

3.1. Requisitos de desempenho

Tempo de resposta: O sistema deve fornecer atualizações em tempo real sobre o estado dos pacientes na UTI. O tempo de resposta para a exibição de dados após a coleta não deve exceder 5 segundos.

Confiabilidade: O sistema deve ter uma taxa de disponibilidade de pelo menos 99,9%. Isso significa que o tempo de inatividade do sistema não deve exceder 8,76 horas por ano.

3.2. Requisitos de segurança

Controles de acesso: O sistema deve implementar controles de acesso rigorosos para garantir que apenas pessoas autorizadas possam acessar os dados do paciente. Isso deve incluir autenticação de dois fatores e controle de acesso baseado em funções.

Criptografia: Todos os dados em repouso e em trânsito devem ser criptografados usando algoritmos de criptografia de padrão industrial.

Auditoria e monitoramento: O sistema deve ter capacidade de auditoria e monitoramento para detectar e responder a possíveis violações de segurança. Isso deve incluir logs de auditoria detalhados e alertas em tempo real para atividades suspeitas.

4. Anexos

4.1 Diagrama de fluxo de trabalho
O anexo A apresenta um diagrama de fluxo de trabalho que ilustra como os dados são coletados, processados e apresentados pelo SMPU.

4.2 Tabela de especificações técnicas
O anexo B fornece uma tabela de especificações técnicas para o SMPU, incluindo requisitos de hardware, software e rede.

4.3 Lista de equipamentos médicos compatíveis
O anexo C fornece uma lista de dispositivos médicos que são compatíveis com o SMPU.

4.4 Diretrizes de instalação e manutenção
O anexo D fornece diretrizes detalhadas para a instalação e manutenção do SMPU.

4.5 Manual do usuário
O anexo E fornece um manual do usuário detalhado para o SMPU. O manual inclui instruções passo a passo sobre como usar o sistema e como resolver problemas comuns.

4.6 Documentação da API
O anexo F fornece documentação detalhada para a API do SMPU. A documentação inclui descrições de todas as chamadas de API, parâmetros, tipos de dados de retorno e códigos de erro.

4.7 Plano de testes
O anexo G apresenta um plano de testes para o SMPU. O plano inclui uma lista de testes a serem realizados, critérios de aceitação para cada teste e um cronograma para a execução dos testes.
"""

# %%
def text_to_df(texto: str) -> pd.DataFrame:
    """
    Converte um texto em um DataFrame, onde cada linha representa uma sentença.

    Parâmetros:
        texto (str): O texto a ser convertido.

    Retorna:
        pd.DataFrame: Um DataFrame contendo as sentenças extraídas do texto.
    """
    
    # Limpeza e tratamento do texto
    texto = re.sub(r"\n+", "\n", texto)  # Removendo linhas vazias
    sentencas = [s.strip() for s in re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', texto) if s and not re.match(r'^\d+(\.\d+)*\.$', s.strip())]
    
    # Agregando linhas que parecem "incompletas"
    i = 0
    while i < len(sentencas) - 1:
        if len(sentencas[i].split()) <= 2:  # Se a sentença é curta (e.g., "3.1. Requisitos de desempenho" ou "Eng.")
            sentencas[i] = sentencas[i] + " " + sentencas[i+1]
            del sentencas[i+1]
        else:
            i += 1

    # Convertendo as sentenças em um DataFrame
    return pd.DataFrame(sentencas, columns=['Sentença'])

# %%
df_smh = text_to_df(smh)

# %%
df_scta = text_to_df(scta)

# %%
df_smpu = text_to_df(smpu)

# %%
def preprocess(text):
    # Convertendo para minúsculo
    text = text.lower()
    
    # Tokenização
    tokens = word_tokenize(text)
    
    # Removendo stopwords e pontuação
    stop_words = set(stopwords.words('portuguese'))
    tokens = [word for word in tokens if word not in stop_words and word not in string.punctuation]
    
    return " ".join(tokens)

# %%
df_all = pd.concat([df_smh, df_scta, df_smpu], ignore_index=True)

# %%
df_all['Sentença'] = df_all['Sentença'].apply(preprocess)

# %%
df_all['label'] = ''

# %%
df_all.rename(columns={'Sentença': 'data'}, inplace=True)

# %%
import json

def to_jsonl(df, output_filename):
    with open(output_filename, 'w', encoding='utf-8') as file:
        for _, row in df.iterrows():
            data = {
                "text": row['data'],
                "entities": [],
                "cats": []
            }
            file.write(json.dumps(data) + '\n')

# %%
to_jsonl(df_all, 'base_tratada.jsonl')
